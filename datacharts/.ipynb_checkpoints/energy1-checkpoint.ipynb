# %%
import pandas as pd
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

# %%
data = pd.read_csv('inoutdata1.csv')
data['ds'] = pd.to_datetime(data['ds'],dayfirst=True)

# %%
#create model for prophet
model = Prophet()
model.fit(data)
# Out:
# 14:03:30 - cmdstanpy - INFO - Chain [1] start processing
# 14:03:30 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=365)

# %%
forecast = model.predict(future)

# %%
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
#             ds         yhat  yhat_lower   yhat_upper
# 367 2024-08-27  1172.471347 -441.613274  2698.531038
# 368 2024-08-28  1173.459623 -422.767724  2750.706523
# 369 2024-08-29  1174.447900 -331.235257  2645.514129
# 370 2024-08-30  1175.436177 -306.918263  2859.240742
# 371 2024-08-31  1176.424453 -290.209647  2739.083358

# %%
fig1 = model.plot(forecast)
fig2 = model.plot_components(forecast)

# %%
plot_plotly(model, forecast)
